# %%
import pandas as pd

# %%
konjunkturklockan = pd.read_csv("../CSV-files/konjunkturklockan.csv")
konjunkturklockan.head()
# Out:
#                indikator;tabellinnehåll;månad;Värde
# 0  BNP-indikator månad;Konjunkturläge;2000M01;-1.07
# 1  BNP-indikator månad;Konjunkturläge;2000M02;-0.84
# 2  BNP-indikator månad;Konjunkturläge;2000M03;-0.59
# 3  BNP-indikator månad;Konjunkturläge;2000M04;-0.29
# 4   BNP-indikator månad;Konjunkturläge;2000M05;0.01

# %%
fruktbarhet_kommun = pd.read_csv("../CSV-files/FertilitetPerKommun.csv")
fruktbarhet_kommun.head()
# Out:
#    region;kön;tabellinnehåll;år;Värde
# 0  Upplands Väsby;män;Antal;2000;1.43
# 1  Upplands Väsby;män;Antal;2001;1.52
# 2  Upplands Väsby;män;Antal;2002;1.51
# 3  Upplands Väsby;män;Antal;2003;1.64
# 4  Upplands Väsby;män;Antal;2004;1.56

# %%
fruktbarhet_rike = pd.read_csv("../CSV-files/Fruktbarhet_riket.csv")
fruktbarhet_rike.head()
# Out:
#      region  kön    år  Summerad fruktsamhet, antal
# 0  00 Riket  män  2000                         1.42
# 1  00 Riket  män  2001                         1.44
# 2  00 Riket  män  2002                         1.52
# 3  00 Riket  män  2003                         1.57
# 4  00 Riket  män  2004                         1.61

# %%
befolkning_tathet = pd.read_csv("../CSV-files/befolkningstathet.csv")
befolkning_tathet.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 befolkning_tathet = pd.read_csv("../CSV-files/befolkningstathet.csv")
#       2 befolkning_tathet.head()
#
# File c:\Users\karlb\anaconda\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...
